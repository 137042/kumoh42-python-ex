# %% [markdown]
# <a href="https://colab.research.google.com/github/137042/python-ex/blob/main/py_builtin_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""Untitled17.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1DICd0pKvwTEMlcLopI_Vxn0Q6XFryxjH
"""

print('hello')



"""나는 킹왕짱이다

"""

# 파이썬에서 제공하는 파이썬 특유의 함수? 내장함수
# 함수 -> 2개, + 함수형 프로그래밍에 대해
# 클래스 -> 전역 메소드, 상속, 인터페이스(파이썬은 인터페이스가 없어요!)
# 예외처리 -> try ecxept else finall + 커스텀 예외 만들기
# -> 로컬로 돌아가서 모듈, 라이브러리

"""1. 내장함수 -> 기본 함수 
파이썬에서 제공하는 문제를 쉽게 해결할 수 있는 함수 
"""

# abs(x) -> 절대값을 만들어주는 기본함수

abs(-2)

abs(1)

# iterable -> 반복 가능한 -> 배열, 리스트, string
# [true, true, true, true, true,,,,,,false]

#for i in arr :
#  if i == false:
#    return false;

arr = [True, True, True, True, True, True, False, True, True]
all(arr)

arr = [True, True, True, True, True, True, True, True, True]
all(arr)

arr = [False, False, False, False, False, False, False, False, False]
any(arr)

arr = [False, False, True, False, False, False, False, False, False]
any(arr)

chr(97)

chr(10)

chr(65)

arr = [1,2,3,4,]

dir(arr)

print(arr)

divmod(10,3)

a, b = divmod(10,3)

a

arr = ['head','body','arm','leg','brain']

for i, name in enumerate(arr):
  if(name == 'arm'):
    arr[i] = "deleted"

arr

arr = ['head','body','arm','leg','brain']

for i in range(len(arr)):
  if(arr[i] == 'arm'):
    arr[i] = 'deleted'

arr

print('1+2')

eval('1+2')

eval('divmod(10,3)')

eval("'hi' + 'python'")

def pos(arr):
  l = []
  for i in arr:
    if i > 0:
      l.append(i)
  return l

pos([1,2,3,-1,2,-12,-99])

def pos2(x):
  return x > 0

def pos3(x):
  return x < 13

list( filter (pos2, [1,2,3,-1,2,-12,-99]))

list( filter (pos3, [1,2,3,-1,2,-12,-99]))

filter (pos3, [1,2,3,-1,2,-12,-99])

dir(filter (pos3, [1,2,3,-1,2,-12,-99]))

k = lambda x,y:x+y

k(1,2)

k1 = lambda x,y,z:x+y-z

k1(1,2,3)

hex(123)

a= 1
hex(id(a))

int('3')

isinstance()

class man: pass

class woman: pass

m = man()

w = woman()

isinstance(m, man)

isinstance(1, man)

isinstance(w, man)

isinstance(w, woman)

list("string")

def pos2(x):
  return x > 3

arr = [1,2,3,4,5,6]

result = list(map(pos2,arr))

any(result)

arr = [1,3,5,7,9,11,13,15,17,18,19,21,23,25,27,29,31]

def check(x):
  return x % 2 == 0

all(list(map(check, arr)))

"""배열이 1 ~ 6까지 있습니다

그중 3보다 큰 수가 있는지 확인하고 싶습니다
"""

max(arr)

min(arr)

max("kim")

min("min")

dir("min")

k = [1,2,3,4,5,6,7,8]
b = ["a","b","c","d","e","f","g","h"]

list(zip(k,b))

def test():
  return 1, 2, 3

test()

a, b, c = test()

a

def test2(*arg):
  print(arg)
  for i, n in enumerate(arg):
    print(i, n)

test2("kim")

test2("kim","jeon")

test2("kim","jeon","chei")

test2("kim","jeon","chei")

def test2(**arg):
  print(arg)
  for i in arg.keys():
    print(i)

test2(name1 = "kim", name2 = "jeon", name3 = "chei")

def test2(*arg1,**arg2):
  print(arg1)
  print(arg2)

test2("kim", "test", name1 = "kim", name2 = "jeon", name3 = "chei")

def test3(a, b):
  print(a)
  print(b)

test3()

def test(a,b,c,d):
  return a(c,d) + b(c,d)

def add(a,b):
  return a+b

def minus(a,b):
  return a-b

test(add,minus,1,2)

def mul(a,b):
  return a*b

test(mul,add,1,2)

def test(a,b,c,d):
  return a(b(c,d),d)

test(mul,add,1,2)

test(add,mul,1,2)

test(minus,mul,1,2)

test(mul,minus,1,2)

k = lambda x,y:x+y

test(k,mul,1,2)

def test5(a,b, *c):
  return a(c)

test5(pos, any, 1,2,3,0,5)

def test6(a,b,c,d,e):
  return a(b(d,e),c(d,e))

test6(mul,add,minus,1,2)

class cal:
  def add(a,b):
    return a+b

cal.add(1,2)

class newCal:
  def add(a,b):
    print(a,b)
    return a+b

test6(mul,cal.add,minus,1,2)

test6(mul,newCal.add,minus,1,2)

class person():
  b = 0
  def __init__(self):
    self.a = 0
    person.b = person.b + 1
  
  def getName(self):
    return self.a
  
  def add(self, a,b):
    return self.a+b

person1 = person()
person2 = person()

person1.a

person2.a

person.b

person1.getName()

person.getName(person1)

person.add(1,2)

person1.add(1,2)

class person():

  def __init__(self, a, b):
    self.a = a
    self.b = b
    self.name
  
  def add(self):
    return self.a + self.b

person1 = person(4,5)

person1.add()

class man(person):
  pass

man = man(1,2)

man.add()

class Job:
  def mySelf(self) -> None:
    print(f'{self.work} 일 합니다.')

class teacher(Job):
  work = "선생님"

class mother(Job):
  work = "엄마"

t = mother()

t.mySelf()

print(100/0)

print("kim")

try:
  result = 100/0
except ZeroDivisionError:
  print("에러 발생")
else:
  print(result)
finally:
  print("kim")

def get(x):
  if x == "kim":
    raise ZeroDivisionError()
  result = 100 / x

try:
  get("kim")
except ZeroDivisionError:
  print("에러 발생")
else:
  print(result)
finally:
  print("kim")

class newError(Exception):
  def __str__(self):
    return " this is my error"

def test():
  raise newError()

try:
  test()
except newError as e:
  print(e)
  print("에러 발생")
else:
  print(result)
finally:
  print("kim")
